# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# 'Gradient Boosting' - 0.409139681201835
# 'Random Forest' - 0.418003472525696
# 'K-Nearest Neighbors' - 0.5833062453519248
# 'Neural Nets' - 0.6118477860455791
# 'Ridge Regression'  - 0.6321048566701682 
# 'Linear Regression' - 0.6321334547789854
# 'Lasso Regression' - 4.29240442615355

objects = (
    'Gradient Boosting', 
    'Random Forest',
    'K-Nearest Neighbors', 
    'Neural Nets', 
    'Ridge Regression', 
    'Linear Regression',
#     'Lasso Regression'
)

y_pos = np.arange(len(objects))
performance = [
    0.409139681201835,
    0.418003472525696,
    0.5833062453519248,
    0.6118477860455791,
    0.6321048566701682,
    0.6321334547789854,
#     4.29240442615355
]

fig, ax = plt.subplots()
ax.barh(y_pos, performance)
plt.yticks(y_pos, objects)
ax.invert_yaxis()
plt.xlabel('Log Loss')

# plt.bar(y_pos, performance, align='center', alpha=0.5)
# plt.xticks(y_pos, objects, rotation=90)
# plt.ylabel('Log Loss')


plt.show()
